# %%
#Libraries
import pandas as pd
import numpy as np
from termcolor import colored
import plotly.express as px
import plotly.offline as pyo
import plotly.graph_objs as go
import plotly.io as pio
from IPython.display import Image

# %%
#Data Bases
companies = pd.read_csv('raw_data/comp_annual_1999_to_2023_allcomp.csv')
compensations = pd.read_csv('raw_data/comp_execucomp_1999_to_2022_allcomp.csv')
# Out:
# C:\Users\gbasulto\AppData\Local\Temp\ipykernel_11296\3547562098.py:2: DtypeWarning:
#
# Columns (26,30,948,949,950,955,958,969,970,975) have mixed types. Specify dtype option on import or set low_memory=False.
#
# C:\Users\gbasulto\AppData\Local\Temp\ipykernel_11296\3547562098.py:3: DtypeWarning:
#
# Columns (96) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
#Numer of obervations 
print("Observations of companies' performance:  ", companies.shape)
print("Observations of CEO compensations:   ", compensations.shape)
# Out:
# Observations of companies' performance:   (259145, 981)
# Observations of CEO compensations:    (266686, 107)

# %%
#Change column names to lower case
compensations.columns = compensations.columns.str.lower()

# %%
#Companies columns
companies.columns
# Out:
# Index(['gvkey', 'datadate', 'fyear', 'indfmt', 'consol', 'popsrc', 'datafmt',
#        'tic', 'cusip', 'conm',
#        ...
#        'priusa', 'sic', 'spcindcd', 'spcseccd', 'spcsrc', 'state', 'stko',
#        'weburl', 'dldte', 'ipodate'],
#       dtype='object', length=981)

# %%
#Variables for Compensation
compensations.columns
# Out:
# Index(['exec_fullname', 'cfoann', 'execdir', 'old_datafmt_flag', 'interlock',
#        'reprice', 'execrank', 'co_per_rol', 'coname', 'titleann',
#        ...
#        'tele', 'sicdesc', 'naicsdesc', 'inddesc', 'spcode', 'ticker',
#        'sub_tele', 'naics', 'spindex', 'sic'],
#       dtype='object', length=107)

# %%
#Number of companies and CEOs in each DataSet
print("Unique companies' performance info:  ",len(companies["gvkey"].unique()))
print("Unique CEOs info:  ",len(compensations["execid"].unique()))
# Out:
# Unique companies' performance info:   25484
# Unique CEOs info:   47847

# %%
#Fiscal Years of obervations
print("Company info from: ", int(min(companies["fyear"].unique())), "to ", int(max(companies["fyear"].unique())))
print("CEO info from: ", int(min(compensations["year"].unique())), "to ", int(max(compensations["year"].unique())))
# Out:
# Company info from:  1998 to  2023
# CEO info from:  1999 to  2022

# %%
#Percetage of Missing Values in CEO compensations DataFrame
Miss = round((compensations.isnull().sum(axis = 0)/compensations.shape[0])*100,2)
for (c, p) in zip(Miss.index, Miss):
    if p>80:
        print(colored(c, "red"), "\t", colored(p, "red"))
    else:
        print(c, "\t", p)
# Out:
# exec_fullname 	 0.0
# cfoann 	 87.27
# execdir 	 0.0
# old_datafmt_flag 	 0.0
# interlock 	 0.0
# reprice 	 0.0
# execrank 	 94.26
# co_per_rol 	 0.0
# coname 	 0.0
# titleann 	 12.34
# ceoann 	 82.54
# salary 	 0.0
# bonus 	 0.0
# stock_awards 	 30.12
# option_awards 	 30.12
# noneq_incent 	 30.12
# pension_chg 	 30.12
# othcomp 	 0.0
# total_sec 	 30.2
# total_curr 	 0.0
# total_alt1 	 33.34
# total_alt2 	 33.37
# term_pymt 	 33.32
# chg_ctrl_pymt 	 33.29
# shrown_tot 	 33.74
# shrown_tot_pct 	 47.18
# shrown_excl_opts 	 10.45
# shrown_excl_opts_pct 	 40.22
# opt_exer_num 	 8.09
# opt_exer_val 	 8.09
# shrs_vest_num 	 33.37
# shrs_vest_val 	 33.37
# age 	 20.73
# option_awards_num 	 3.2
# option_awards_fv 	 33.32
# stock_awards_fv 	 33.29
# opt_unex_exer_num 	 7.98
# opt_unex_unexer_num 	 7.98
# opt_unex_exer_est_val 	 7.98
# opt_unex_unexer_est_val 	 7.98
# stock_unvest_num 	 7.97
# stock_unvest_val 	 7.97
# eip_unearn_num 	 33.26
# eip_unearn_val 	 33.26
# pension_value_tot 	 33.35
# pension_pymts_tot 	 33.35
# defer_contrib_exec_tot 	 33.35
# defer_contrib_co_tot 	 33.35
# defer_earnings_tot 	 33.35
# defer_withdr_tot 	 33.35
# defer_balance_tot 	 33.35
# defer_rpt_as_comp_tot 	 33.35
# execrankann 	 12.34
# othann 	 69.88
# tdc1 	 7.25
# tdc2 	 3.23
# rstkgrnt 	 69.88
# option_awards_blk_value 	 73.89
# option_awards_rpt_value 	 73.96
# ltip 	 69.88
# allothtot 	 69.88
# allothpd 	 69.88
# sal_pct 	 17.2
# total_curr_pct 	 17.19
# total_sec_pct 	 45.83
# total_alt1_pct 	 49.69
# total_alt2_pct 	 49.73
# tdc1_pct 	 26.6
# tdc2_pct 	 21.17
# ret_yrs 	 91.99
# comment 	 97.59
# gvkey 	 0.0
# execid 	 0.0
# year 	 0.0
# rstkvyrs 	 99.84
# becameceo 	 73.38
# joined_co 	 79.09
# rejoin 	 99.86
# leftofc 	 81.95
# leftco 	 89.73
# releft 	 99.94
# pceo 	 89.16
# pcfo 	 93.72
# title 	 1.21
# reason 	 89.89
# exec_lname 	 0.0
# exec_fname 	 0.0
# exec_mname 	 12.73
# gender 	 0.0
# nameprefix 	 0.03
# page 	 7.72
# cusip 	 0.0
# exchange 	 0.0
# address 	 0.0
# city 	 0.0
# state 	 2.36
# zip 	 0.08
# tele 	 1.43
# sicdesc 	 0.0
# naicsdesc 	 0.0
# inddesc 	 0.02
# spcode 	 0.0
# ticker 	 0.0
# sub_tele 	 2.98
# naics 	 0.0
# spindex 	 0.02
# sic 	 0.0

# %%
#Drop Some Columns with too many Missing Values
col_keep_comp = ['execid', 'age', 'coname', 'year', 'salary', 'tdc1', 'tdc2', 'total_curr', 'ceoann', 'joined_co', 'titleann', 'becameceo', 'gvkey']
compensations = compensations[col_keep_comp]
compensations.dropna(subset = ["tdc1"], inplace = True)
#We should have 0 missing values now
compensations.isnull().sum(axis = 0).sum()
# Out:
# 632427

# %%
#We do the same for the Compannies Dataframe
#Percetage of Missing Values in Companies DataFrame
Miss = round((companies.isnull().sum(axis = 0)/companies.shape[0])*100,2)
for (c, p) in zip(Miss.index, Miss):
    if p>80:
        print(colored(c, "red"), "\t", colored(p, "red"))
    else:
        print(c, "\t", p)
# Out:
# gvkey 	 0.0
# datadate 	 0.0
# fyear 	 0.0
# indfmt 	 0.0
# consol 	 0.0
# popsrc 	 0.0
# datafmt 	 0.0
# tic 	 0.04
# cusip 	 0.04
# conm 	 0.0
# acctchg 	 92.98
# acctstd 	 17.5
# acqmeth 	 89.23
# adrr 	 94.46
# ajex 	 0.0
# ajp 	 0.0
# bspr 	 76.07
# compst 	 82.47
# curcd 	 0.0
# curncd 	 0.0
# currtr 	 0.0
# curuscn 	 98.34
# final 	 16.08
# fyr 	 0.0
# ismod 	 28.53
# ltcm 	 72.14
# ogm 	 98.24
# pddur 	 0.0
# scf 	 30.28
# src 	 15.27
# stalt 	 99.68
# udpl 	 97.41
# upd 	 0.0
# apdedate 	 38.66
# fdate 	 45.85
# pdate 	 73.86
# acchg 	 34.57
# acco 	 93.43
# accrt 	 97.77
# acdo 	 45.31
# aco 	 34.78
# acodo 	 45.15
# acominc 	 37.29
# acox 	 36.35
# acoxar 	 99.67
# acqao 	 97.84
# acqcshi 	 96.23
# acqgdwl 	 94.68
# acqic 	 98.54
# acqintan 	 94.73
# acqinvt 	 97.98
# acqlntal 	 99.63
# acqniintc 	 99.97
# acqppe 	 96.31
# acqsc 	 97.78
# act 	 41.02
# adpac 	 98.85
# aedi 	 98.04
# afudcc 	 99.07
# afudci 	 99.07
# aldo 	 45.15
# am 	 44.8
# amc 	 99.64
# amdc 	 97.21
# amgw 	 90.21
# ano 	 73.71
# ao 	 17.52
# aocidergl 	 42.8
# aociother 	 41.77
# aocipen 	 42.49
# aocisecgl 	 41.84
# aodo 	 45.11
# aol2 	 73.74
# aoloch 	 30.63
# aox 	 24.74
# ap 	 24.94
# apalch 	 53.96
# apb 	 96.58
# apc 	 96.76
# apofs 	 96.55
# aqa 	 90.1
# aqc 	 32.91
# aqd 	 90.34
# aqeps 	 90.34
# aqi 	 66.45
# aqp 	 90.07
# aqpl1 	 73.72
# aqs 	 66.38
# arb 	 96.58
# arc 	 97.03
# arce 	 99.97
# arced 	 99.97
# arceeps 	 99.97
# artfs 	 96.24
# at 	 17.5
# aul3 	 73.73
# autxr 	 96.14
# balr 	 99.42
# banlr 	 99.53
# bast 	 94.8
# bastr 	 94.43
# batr 	 99.7
# bcef 	 99.38
# bclr 	 99.41
# bcltbl 	 98.89
# bcnlr 	 99.46
# bcrbl 	 98.98
# bct 	 98.73
# bctbl 	 98.94
# bctr 	 99.61
# billexce 	 96.46
# bkvlps 	 31.21
# bltbl 	 98.96
# ca 	 93.41
# capr1 	 93.65
# capr2 	 93.77
# capr3 	 93.61
# caps 	 20.53
# capsft 	 94.81
# capx 	 30.86
# capxv 	 35.86
# cb 	 99.61
# cbi 	 99.01
# cdpac 	 99.24
# cdvc 	 97.44
# ceiexbill 	 97.62
# ceq 	 17.71
# ceql 	 29.38
# ceqt 	 29.39
# cfbd 	 99.33
# cfere 	 98.56
# cfo 	 92.21
# cfpdo 	 90.89
# cga 	 96.14
# cgri 	 98.97
# cgti 	 98.95
# cgui 	 98.91
# ch 	 18.55
# che 	 28.08
# chech 	 30.48
# chs 	 99.28
# ci 	 59.42
# cibegni 	 49.81
# cicurr 	 50.11
# cidergl 	 50.18
# cimii 	 59.44
# ciother 	 49.83
# cipen 	 49.97
# cisecgl 	 50.17
# citotal 	 49.8
# cld2 	 52.34
# cld3 	 52.44
# cld4 	 52.26
# cld5 	 52.36
# clfc 	 99.91
# clfx 	 99.85
# clg 	 94.14
# clis 	 99.78
# cll 	 99.77
# cllc 	 99.82
# clo 	 99.9
# clrll 	 97.13
# clt 	 99.98
# cmp 	 95.14
# cnltbl 	 98.95
# cogs 	 28.43
# cpcbl 	 99.41
# cpdoi 	 99.04
# cpnli 	 99.05
# cppbl 	 99.36
# cprei 	 99.07
# crv 	 96.13
# crvnli 	 98.79
# cshfd 	 31.8
# cshi 	 30.05
# csho 	 14.6
# cshpri 	 31.52
# cshr 	 42.9
# cshrc 	 100.0
# cshrp 	 100.0
# cshrso 	 100.0
# cshrt 	 99.99
# cshrw 	 100.0
# cstk 	 20.11
# cstkcv 	 31.88
# cstke 	 17.86
# dbi 	 99.37
# dc 	 39.39
# dclo 	 38.16
# dcom 	 45.24
# dcpstk 	 35.89
# dcs 	 77.02
# dcvsr 	 38.14
# dcvsub 	 38.12
# dcvt 	 32.0
# dd 	 38.66
# dd1 	 22.81
# dd2 	 46.11
# dd3 	 46.36
# dd4 	 46.14
# dd5 	 46.86
# depc 	 97.44
# derac 	 94.58
# deralt 	 94.26
# derhedgl 	 93.07
# derlc 	 93.17
# derllt 	 93.02
# dfpac 	 98.75
# dfs 	 80.79
# dfxa 	 90.24
# diladj 	 31.27
# dilavx 	 31.27
# dlc 	 18.18
# dlcch 	 61.57
# dltis 	 32.52
# dlto 	 34.35
# dltp 	 49.07
# dltr 	 31.87
# dltsub 	 96.2
# dltt 	 17.71
# dm 	 40.69
# dn 	 38.56
# do 	 17.86
# donr 	 47.2
# dp 	 21.42
# dpacb 	 100.0
# dpacc 	 100.0
# dpacli 	 100.0
# dpacls 	 100.0
# dpacme 	 100.0
# dpacnr 	 100.0
# dpaco 	 100.0
# dpacre 	 98.25
# dpact 	 35.04
# dpc 	 32.04
# dpdc 	 97.83
# dpltb 	 99.66
# dpret 	 98.21
# dpsc 	 97.95
# dpstb 	 99.66
# dptb 	 99.65
# dptc 	 91.58
# dptic 	 97.82
# dpvieb 	 40.48
# dpvio 	 100.0
# dpvir 	 100.0
# drc 	 48.52
# drci 	 99.85
# drlt 	 46.32
# ds 	 38.18
# dt 	 37.5
# dtea 	 90.7
# dted 	 91.05
# dteeps 	 91.05
# dtep 	 90.69
# dudd 	 36.15
# dv 	 31.76
# dvc 	 18.99
# dvdnp 	 96.15
# dvintf 	 96.78
# dvp 	 17.92
# dvpa 	 38.13
# dvpd 	 96.27
# dvpdp 	 98.81
# dvpibb 	 100.0
# dvrpiv 	 96.21
# dvrre 	 98.54
# dvsco 	 96.14
# dvt 	 18.99
# dxd2 	 51.24
# dxd3 	 51.4
# dxd4 	 51.16
# dxd5 	 51.67
# ea 	 96.13
# ebit 	 28.78
# ebitda 	 30.36
# eiea 	 96.14
# emol 	 99.85
# emp 	 25.55
# epsfi 	 31.53
# epsfx 	 31.53
# epspi 	 31.52
# epspx 	 31.52
# esopct 	 34.36
# esopdlt 	 61.85
# esopnr 	 44.91
# esopr 	 45.13
# esopt 	 34.44
# esub 	 37.22
# esubc 	 38.19
# excadj 	 96.13
# exre 	 30.62
# fatb 	 51.17
# fatc 	 50.44
# fatd 	 98.2
# fate 	 55.35
# fatl 	 53.02
# fatn 	 50.16
# fato 	 57.77
# fatp 	 50.94
# fca 	 66.03
# fdfr 	 90.01
# fea 	 99.64
# fel 	 99.64
# ffo 	 98.9
# ffs 	 90.2
# fiao 	 30.52
# finaco 	 99.91
# finao 	 99.9
# fincf 	 30.5
# finch 	 99.89
# findlc 	 99.91
# findlt 	 99.88
# finivst 	 99.94
# finlco 	 99.93
# finlto 	 99.93
# finnp 	 99.9
# finrecc 	 99.85
# finreclt 	 99.88
# finrev 	 99.82
# finxint 	 99.88
# finxopr 	 99.86
# fopo 	 30.57
# fopox 	 46.71
# fopt 	 99.96
# fsrco 	 99.96
# fsrct 	 99.96
# fuseo 	 99.96
# fuset 	 99.96
# gbbl 	 99.35
# gdwl 	 22.66
# gdwlam 	 95.93
# gdwlia 	 95.09
# gdwlid 	 95.26
# gdwlieps 	 95.26
# gdwlip 	 95.07
# geqrv 	 96.13
# gla 	 92.67
# glcea 	 82.79
# glced 	 83.45
# glceeps 	 83.45
# glcep 	 82.77
# gld 	 92.88
# gleps 	 92.88
# gliv 	 95.48
# glp 	 92.65
# govgr 	 96.13
# govtown 	 96.23
# gp 	 28.43
# gphbl 	 99.33
# gplbl 	 99.28
# gpobl 	 99.26
# gprbl 	 99.27
# gptbl 	 99.34
# gwo 	 96.15
# hedgegl 	 92.88
# iaeq 	 98.91
# iaeqci 	 98.97
# iaeqmi 	 98.91
# iafici 	 98.94
# iafxi 	 98.9
# iafxmi 	 98.9
# iali 	 99.98
# ialoi 	 98.9
# ialti 	 98.91
# iamli 	 98.92
# iaoi 	 98.89
# iapli 	 98.91
# iarei 	 98.94
# iasci 	 98.95
# iasmi 	 98.9
# iassi 	 98.9
# iasti 	 98.89
# iatci 	 99.01
# iati 	 98.73
# iatmi 	 98.91
# iaui 	 99.98
# ib 	 17.87
# ibadj 	 28.42
# ibbl 	 99.35
# ibc 	 30.59
# ibcom 	 28.42
# ibki 	 99.3
# ibmii 	 58.11
# icapt 	 17.65
# idiis 	 98.37
# idilb 	 98.42
# idilc 	 97.25
# idis 	 97.98
# idist 	 97.47
# idit 	 47.76
# idits 	 98.49
# iire 	 98.53
# initb 	 93.27
# intan 	 20.3
# intano 	 29.95
# intc 	 35.04
# intpn 	 39.76
# invch 	 35.77
# invfg 	 53.01
# invo 	 52.4
# invofs 	 97.6
# invreh 	 97.62
# invrei 	 97.61
# invres 	 97.61
# invrm 	 53.06
# invt 	 26.45
# invwip 	 53.45
# iobd 	 99.29
# ioi 	 98.74
# iore 	 98.51
# ip 	 97.56
# ipabl 	 99.28
# ipc 	 97.63
# iphbl 	 99.33
# iplbl 	 99.28
# ipobl 	 99.26
# iptbl 	 99.34
# ipti 	 97.36
# ipv 	 98.83
# irei 	 99.03
# irent 	 92.47
# irii 	 98.95
# irli 	 99.05
# irnli 	 99.05
# irsi 	 98.98
# iseq 	 98.53
# iseqc 	 98.63
# iseqm 	 98.55
# isfi 	 98.58
# isfxc 	 98.7
# isfxm 	 98.61
# isgr 	 98.91
# isgt 	 92.44
# isgu 	 98.8
# islg 	 98.52
# islgc 	 98.52
# islgm 	 98.52
# islt 	 99.36
# isng 	 98.51
# isngc 	 98.57
# isngm 	 98.53
# isotc 	 98.74
# isoth 	 98.54
# isotm 	 98.61
# issc 	 98.55
# issm 	 98.51
# issu 	 98.49
# ist 	 91.64
# istc 	 98.64
# istm 	 98.47
# isut 	 99.36
# itcb 	 35.48
# itcc 	 98.64
# itci 	 53.34
# ivaco 	 30.52
# ivaeq 	 23.68
# ivao 	 30.65
# ivch 	 33.1
# ivgod 	 96.32
# ivi 	 97.6
# ivncf 	 30.5
# ivpt 	 89.65
# ivst 	 18.9
# ivstch 	 47.27
# lcabg 	 99.35
# lcacl 	 96.7
# lcacr 	 96.66
# lcag 	 99.38
# lcal 	 96.83
# lcalt 	 99.69
# lcam 	 96.72
# lcao 	 90.65
# lcast 	 99.69
# lcat 	 99.57
# lco 	 34.78
# lcox 	 35.46
# lcoxar 	 99.72
# lcoxdr 	 45.12
# lct 	 40.81
# lcuacu 	 90.45
# li 	 96.19
# lif 	 99.01
# lifr 	 40.49
# lifrp 	 40.92
# lloml 	 97.13
# lloo 	 97.13
# llot 	 97.13
# llrci 	 97.12
# llrcr 	 97.03
# llwoci 	 97.11
# llwocr 	 97.0
# lno 	 73.73
# lo 	 17.52
# lol2 	 73.75
# loxdr 	 45.11
# lqpl1 	 73.74
# lrv 	 96.13
# ls 	 96.13
# lse 	 17.5
# lst 	 99.33
# lt 	 17.63
# lul3 	 73.74
# mib 	 19.67
# mibn 	 57.38
# mibt 	 20.42
# mii 	 21.95
# mrc1 	 49.49
# mrc2 	 51.53
# mrc3 	 51.66
# mrc4 	 51.71
# mrc5 	 53.46
# mrct 	 53.65
# mrcta 	 52.18
# msa 	 31.64
# msvrv 	 99.99
# mtl 	 99.27
# nat 	 100.0
# nco 	 93.51
# nfsr 	 96.27
# ni 	 28.42
# niadj 	 28.42
# nieci 	 97.97
# niint 	 91.12
# niintpfc 	 99.87
# niintpfp 	 99.86
# niit 	 96.01
# nim 	 93.7
# nio 	 96.14
# nipfc 	 97.42
# nipfp 	 97.57
# nit 	 96.14
# nits 	 99.17
# nopi 	 28.44
# nopio 	 35.12
# np 	 28.32
# npanl 	 97.9
# npaore 	 91.72
# nparl 	 98.03
# npat 	 91.67
# nrtxt 	 94.47
# nrtxtd 	 94.6
# nrtxteps 	 94.6
# oancf 	 30.5
# ob 	 86.59
# oiadp 	 28.43
# oibdp 	 30.36
# opeps 	 31.52
# opili 	 99.22
# opincar 	 99.17
# opini 	 99.18
# opioi 	 99.08
# opiri 	 99.03
# opiti 	 99.44
# oprepsx 	 31.61
# optca 	 59.78
# optdr 	 73.84
# optex 	 61.6
# optexd 	 59.79
# optfvgr 	 75.59
# optgr 	 59.6
# optlife 	 73.42
# optosby 	 59.67
# optosey 	 56.58
# optprcby 	 64.23
# optprcca 	 69.29
# optprcex 	 72.76
# optprcey 	 60.86
# optprcgr 	 72.7
# optprcwa 	 66.21
# optrfr 	 73.17
# optvol 	 73.14
# palr 	 99.1
# panlr 	 99.06
# patr 	 99.07
# pcl 	 90.72
# pclr 	 99.08
# pcnlr 	 99.03
# pctr 	 99.02
# pdvc 	 97.9
# pi 	 17.87
# pidom 	 79.22
# pifo 	 79.4
# pll 	 93.33
# pltbl 	 98.94
# pnca 	 54.33
# pncad 	 56.71
# pncaeps 	 56.71
# pncia 	 88.22
# pncid 	 89.18
# pncieps 	 89.18
# pncip 	 88.21
# pncwia 	 87.61
# pncwid 	 88.61
# pncwieps 	 88.61
# pncwip 	 87.61
# pnlbl 	 98.94
# pnli 	 98.93
# pnrsho 	 47.77
# pobl 	 98.91
# ppcbl 	 99.41
# ppegt 	 34.35
# ppenb 	 100.0
# ppenc 	 97.96
# ppenli 	 100.0
# ppenls 	 100.0
# ppenme 	 100.0
# ppennr 	 100.0
# ppeno 	 100.0
# ppent 	 19.94
# ppevbb 	 98.04
# ppeveb 	 38.11
# ppevo 	 100.0
# ppevr 	 100.0
# pppabl 	 99.41
# ppphbl 	 99.41
# pppobl 	 99.41
# ppptbl 	 99.36
# prc 	 96.14
# prca 	 54.54
# prcad 	 56.71
# prcaeps 	 56.71
# prebl 	 98.96
# pri 	 98.97
# prodv 	 96.16
# prsho 	 47.63
# prstkc 	 34.97
# prstkcc 	 97.49
# prstkpc 	 97.45
# prvt 	 99.99
# pstk 	 17.83
# pstkc 	 35.58
# pstkl 	 29.08
# pstkn 	 17.91
# pstkr 	 17.69
# pstkrv 	 29.04
# ptbl 	 98.9
# ptran 	 99.37
# pvcl 	 97.09
# pvo 	 96.13
# pvon 	 95.66
# pvpl 	 96.15
# pvt 	 96.24
# pwoi 	 99.0
# radp 	 98.74
# ragr 	 89.67
# rari 	 98.74
# rati 	 98.74
# rca 	 86.87
# rcd 	 87.35
# rceps 	 87.35
# rcl 	 90.62
# rcp 	 86.83
# rdip 	 42.51
# rdipa 	 43.19
# rdipd 	 44.73
# rdipeps 	 44.73
# rdp 	 96.2
# re 	 19.93
# rea 	 45.93
# reajo 	 31.88
# recch 	 39.34
# recco 	 33.7
# recd 	 52.49
# rect 	 28.61
# recta 	 31.3
# rectr 	 33.79
# recub 	 89.05
# ret 	 98.17
# reuna 	 32.53
# reunr 	 94.35
# revt 	 17.88
# ris 	 89.46
# rll 	 93.34
# rlo 	 98.78
# rlp 	 98.78
# rlri 	 98.73
# rlt 	 98.76
# rmum 	 99.89
# rpag 	 90.09
# rra 	 98.01
# rrd 	 98.09
# rreps 	 98.09
# rrp 	 98.01
# rstche 	 93.04
# rstchelt 	 95.45
# rvbci 	 98.85
# rvbpi 	 98.84
# rvbti 	 98.74
# rvdo 	 96.15
# rvdt 	 96.18
# rveqt 	 96.17
# rvlrv 	 96.14
# rvno 	 96.22
# rvnt 	 96.16
# rvri 	 98.83
# rvsi 	 98.73
# rvti 	 98.72
# rvtxr 	 96.13
# rvupi 	 98.76
# rvutx 	 96.13
# saa 	 98.72
# sal 	 98.73
# sale 	 28.42
# salepfc 	 97.54
# salepfp 	 97.72
# sbdc 	 99.27
# sc 	 99.27
# sco 	 96.14
# scstkc 	 97.43
# secu 	 90.49
# seq 	 17.51
# seqo 	 45.31
# seta 	 92.23
# setd 	 92.43
# seteps 	 92.44
# setp 	 92.22
# siv 	 32.93
# spce 	 68.55
# spced 	 70.19
# spceeps 	 70.19
# spi 	 18.71
# spid 	 90.15
# spieps 	 90.16
# spioa 	 89.82
# spiop 	 89.78
# sppe 	 42.7
# sppiv 	 33.09
# spstkc 	 97.42
# sret 	 98.21
# srt 	 99.07
# ssnp 	 99.25
# sstk 	 31.48
# stbo 	 89.77
# stio 	 90.81
# stkco 	 51.77
# stkcpa 	 78.46
# tdc 	 97.66
# tdscd 	 98.44
# tdsce 	 98.43
# tdsg 	 92.86
# tdslg 	 98.48
# tdsmm 	 98.46
# tdsng 	 98.45
# tdso 	 98.45
# tdss 	 98.43
# tdst 	 91.87
# teq 	 46.88
# tf 	 92.62
# tfva 	 73.72
# tfvce 	 88.28
# tfvl 	 73.75
# tie 	 93.31
# tii 	 93.31
# tlcf 	 54.89
# transa 	 89.92
# tsa 	 96.13
# tsafc 	 100.0
# tso 	 96.13
# tstk 	 18.06
# tstkc 	 18.88
# tstkme 	 100.0
# tstkn 	 28.68
# tstkp 	 18.42
# txach 	 50.03
# txbco 	 46.86
# txbcof 	 50.81
# txc 	 44.49
# txdb 	 25.32
# txdba 	 46.9
# txdbca 	 53.88
# txdbcl 	 54.33
# txdc 	 32.76
# txdfed 	 53.35
# txdfo 	 50.72
# txdi 	 35.42
# txditc 	 37.09
# txds 	 53.55
# txeqa 	 95.95
# txeqii 	 99.41
# txfed 	 48.02
# txfo 	 44.23
# txndb 	 45.31
# txndba 	 49.13
# txndbl 	 49.14
# txndbr 	 47.8
# txo 	 35.73
# txp 	 32.42
# txpd 	 43.63
# txr 	 38.38
# txs 	 48.47
# txt 	 17.88
# txtubadjust 	 78.17
# txtubbegin 	 77.95
# txtubend 	 77.48
# txtubmax 	 94.18
# txtubmin 	 97.24
# txtubposdec 	 78.15
# txtubposinc 	 78.19
# txtubpospdec 	 78.16
# txtubpospinc 	 78.19
# txtubsettle 	 78.18
# txtubsoflimit 	 78.19
# txtubtxtr 	 81.73
# txtubxintbs 	 82.38
# txtubxintis 	 85.79
# txva 	 96.18
# txw 	 42.09
# uaoloch 	 97.44
# uaox 	 97.97
# uapt 	 97.58
# ucaps 	 97.74
# uccons 	 99.87
# uceq 	 97.41
# ucustad 	 99.21
# udcopres 	 97.42
# udd 	 97.62
# udfcc 	 98.57
# udmb 	 97.54
# udolt 	 97.5
# udpco 	 97.77
# udpfa 	 99.64
# udvp 	 97.45
# ufretsd 	 100.0
# ugi 	 97.41
# ui 	 96.99
# uinvt 	 97.51
# ulcm 	 98.06
# ulco 	 97.41
# uniami 	 97.41
# unl 	 96.13
# unnp 	 96.14
# unnpl 	 96.13
# unopinc 	 97.42
# unwcc 	 100.0
# uois 	 97.43
# uopi 	 97.41
# uopres 	 99.34
# updvp 	 97.42
# upmcstk 	 98.39
# upmpf 	 97.68
# upmpfs 	 97.42
# upmsubp 	 97.55
# upstk 	 97.43
# upstkc 	 97.41
# upstksf 	 97.45
# urect 	 97.42
# urectr 	 97.68
# urevub 	 98.06
# uspi 	 97.63
# ustdnc 	 100.0
# usubdvp 	 97.51
# usubpstk 	 97.45
# utfdoc 	 100.0
# utfosc 	 100.0
# utme 	 99.49
# utxfed 	 97.63
# uwkcapc 	 100.0
# uxinst 	 99.96
# uxintd 	 99.41
# vpac 	 96.55
# vpo 	 89.62
# wcap 	 41.51
# wcapc 	 99.97
# wcapch 	 99.98
# wda 	 91.14
# wdd 	 91.44
# wdeps 	 91.44
# wdp 	 91.1
# xacc 	 49.65
# xad 	 73.16
# xago 	 91.96
# xagt 	 90.5
# xcom 	 99.37
# xcomi 	 99.27
# xdepl 	 100.0
# xdp 	 100.0
# xdvre 	 98.58
# xeqo 	 92.71
# xi 	 22.25
# xido 	 17.86
# xidoc 	 30.62
# xindb 	 99.67
# xindc 	 97.85
# xins 	 96.24
# xinst 	 98.91
# xint 	 28.81
# xintd 	 78.64
# xintopt 	 60.29
# xivi 	 98.86
# xivre 	 98.6
# xlr 	 75.89
# xnbi 	 98.61
# xnf 	 96.3
# xnins 	 98.75
# xnitb 	 93.27
# xobd 	 99.41
# xoi 	 98.74
# xopr 	 28.43
# xoprar 	 99.16
# xoptd 	 61.01
# xopteps 	 61.01
# xore 	 98.58
# xpp 	 50.27
# xpr 	 41.71
# xrd 	 64.31
# xrdp 	 68.46
# xrent 	 43.68
# xs 	 89.46
# xsga 	 40.79
# xstf 	 92.02
# xstfo 	 98.92
# xstfws 	 99.76
# xt 	 89.45
# xuw 	 99.64
# xuwli 	 99.04
# xuwnli 	 99.04
# xuwoi 	 98.97
# xuwrei 	 99.0
# xuwti 	 99.0
# exchg 	 0.04
# cik 	 13.29
# costat 	 0.0
# fic 	 0.0
# naicsh 	 14.97
# sich 	 21.29
# cshtr_c 	 11.6
# dvpsp_c 	 7.22
# dvpsx_c 	 7.22
# prcc_c 	 10.47
# prch_c 	 10.46
# prcl_c 	 10.46
# adjex_c 	 7.22
# cshtr_f 	 11.57
# dvpsp_f 	 7.14
# dvpsx_f 	 7.14
# mkvalt 	 34.93
# prcc_f 	 10.44
# prch_f 	 10.43
# prcl_f 	 10.43
# adjex_f 	 7.11
# rank 	 20.32
# au 	 21.97
# auop 	 21.94
# auopic 	 42.87
# ceoso 	 38.33
# cfoso 	 38.33
# add1 	 0.0
# add2 	 99.75
# add3 	 99.96
# add4 	 99.99
# addzip 	 1.12
# busdesc 	 0.19
# city 	 0.0
# conml 	 0.0
# county 	 99.86
# dlrsn 	 58.97
# ein 	 24.58
# fax 	 53.75
# fyrc 	 0.0
# ggroup 	 15.69
# gind 	 15.69
# gsector 	 15.69
# gsubind 	 15.69
# idbflag 	 0.0
# incorp 	 12.64
# loc 	 0.0
# naics 	 3.06
# phone 	 2.14
# prican 	 97.14
# prirow 	 94.49
# priusa 	 0.05
# sic 	 0.0
# spcindcd 	 40.06
# spcseccd 	 40.06
# spcsrc 	 47.66
# state 	 10.57
# stko 	 15.26
# weburl 	 21.86
# dldte 	 58.97
# ipodate 	 54.87

# %%
col_keep = ['conm', 'gvkey', 'ebit','ebitda', 'pi', 'addzip', 
            'city','naics', 'fyear','state', 'sale', 'at', 'mkvalt']
companies = companies[col_keep]

#Percetage of Missing Values in Companies DataFrame is Zero now
companies.isnull().sum(axis = 0).sum()
# Out:
# 447360

# %%
#We also drop companies with negative income and outliers
companies = companies[companies.ebit > 0]
companies = companies[companies.pi > 0]

# %%
# Merge data at CEO level
data = compensations.merge(companies, left_on = ["gvkey", "year"], 
                           right_on = ["gvkey", "fyear"], how = "inner", 
                           suffixes = ("","_y"))
data.drop(data.filter(regex='_y$').columns, axis=1, inplace=True)

data.drop_duplicates(subset=["execid", "year"], inplace = True)

# %%
#Inflation data for Normalization
inflation = pd.read_csv('raw_data/hist_inflation.csv')
inflation = inflation[inflation['Country Code'] == 'USA'].melt()
inflation.columns = ['year', 'inflation_rate']
inflation = inflation.iloc[43:67]
inflation.inflation_rate = inflation.inflation_rate/100
inflation.reset_index(drop = True, inplace = True)
inflation['inflation_rate'][0] = 0
infl_tot = []
for i in range(1,25):
    infl_tot.append(np.prod(1-inflation.inflation_rate.iloc[0:i]))
inflation['inflation_multiplier'] = infl_tot 
inflation.year = inflation.year.astype(int)
inflation
# Out:
#     year inflation_rate  inflation_multiplier
# 0   1999              0              1.000000
# 1   2000       0.033769              0.966231
# 2   2001       0.028262              0.938924
# 3   2002        0.01586              0.924032
# 4   2003       0.022701              0.903056
# 5   2004       0.026772              0.878879
# 6   2005       0.033927              0.849061
# 7   2006       0.032259              0.821671
# 8   2007       0.028527              0.798231
# 9   2008       0.038391              0.767586
# 10  2009      -0.003555              0.770315
# 11  2010         0.0164              0.757682
# 12  2011       0.031568              0.733763
# 13  2012       0.020693              0.718579
# 14  2013       0.014648              0.708053
# 15  2014       0.016222              0.696567
# 16  2015       0.001186              0.695741
# 17  2016       0.012616              0.686963
# 18  2017       0.021301              0.672330
# 19  2018       0.024426              0.655908
# 20  2019       0.018122              0.644021
# 21  2020       0.012336              0.636077
# 22  2021       0.046979              0.606195
# 23  2022       0.080028              0.557682

# %%
#Merge Compensation Data with Inflation Data
data = data.merge(inflation, on = "year",how = "inner")
data.tdc1 = data.tdc1 * data.inflation_multiplier
data.tdc2 = data.tdc2 * data.inflation_multiplier
data.total_curr = data.total_curr * data.inflation_multiplier
data.ebit = data.ebit * data.inflation_multiplier
data.pi = data.pi*data.inflation_multiplier
data.sale = data.sale*data.inflation_multiplier
data.mkvalt = data.mkvalt*data.inflation_multiplier
data.salary = data.salary*data.inflation_multiplier

# %%
data = pd.merge(data, data.groupby(by=["fyear","naics"])["sale"].count().reset_index(),how="inner",
        on=['fyear','naics'])
data.rename(columns={"sale_x": "sale", "sale_y": "size_industry"}, inplace = True)

# %%
#We will also filter CEO with few observations
#Number of CEO with at least k observations
for k in range(1,15):
    print("k = ", k, ",   ", (data.groupby(by = "execid").year.nunique()>=k).sum())
# Out:
# k =  1 ,    41840
# k =  2 ,    32070
# k =  3 ,    25018
# k =  4 ,    19952
# k =  5 ,    16041
# k =  6 ,    12943
# k =  7 ,    10364
# k =  8 ,    8314
# k =  9 ,    6578
# k =  10 ,    5305
# k =  11 ,    4247
# k =  12 ,    3359
# k =  13 ,    2721
# k =  14 ,    2162

# %%
#Filter CEOs with less than ny observations
ny = 3
temp = (data.groupby(by = "execid").year.nunique()>=ny).reset_index()
data = data[data.execid.isin(temp.execid[temp.year])]

# %%
print("Final companies for reggresion:", len(data["coname"].unique()))
# Out:
# Final companies for reggresion: 3070

# %%
print("Final excecutives for reggresion:", len(data["execid"].unique()))
# Out:
# Final excecutives for reggresion: 25018

# %%
print("Final years for reggresion:", data["year"].min(), "to ", data["year"].max())
# Out:
# Final years for reggresion: 1999 to  2022

# %%
#Change Salary observations to millions to match
data = data[data.tdc1>=0]
data = data[data.total_curr>=0]
data.tdc1 = data.tdc1/1000
data.total_curr = data.total_curr/1000
data.tdc2 = data.tdc2/1000
data.salary = data.salary/1000

#Create bonus and future compensation observations

data.bonus = data.total_curr - data.salary #Bonus 
data.fut_comp1 = data.tdc1 - data.total_curr #Future compensations using value of options granted 
data.fut_comp2 = data.tdc2 - data.total_curr #Future compensations using value of options exercised 

#Sort values by CEO and year
data = data.sort_values(["execid","year"]).reset_index(drop = True)
data.head()
# Out:
#    execid   age     coname  year   salary       tdc1          tdc2  \
# 0       7  59.0  ADOBE INC  1999  622.524  14.687721   5295.364000
# 1       7  60.0  ADOBE INC  2000  760.201  42.913783  52684.463293
# 2       7  62.0  ADOBE INC  2001   66.669   1.273491  29374.898772
# 3      13  48.0  AFLAC INC  1999  995.000  10.464222  17848.301000
# 4      13  49.0  AFLAC INC  2000  995.000  10.346627  18972.283560
#
#    total_curr ceoann   joined_co  ...      city     naics  fyear state  \
# 0    1.235033    CEO  19820101.0  ...  San Jose  518210.0   1999    CA
# 1    1.297881    CEO  19820101.0  ...  San Jose  518210.0   2000    CA
# 2    0.062597    NaN  19820101.0  ...  San Jose  518210.0   2001    CA
# 3    2.600930    CEO  19730101.0  ...  Columbus  524114.0   1999    GA
# 4    2.533290    CEO  19730101.0  ...  Columbus  524114.0   2000    GA
#
#           sale         at        mkvalt inflation_rate inflation_multiplier  \
# 0  1015.434000    803.859   8142.147600              0             1.000000
# 1  1223.614222   1069.416  14754.308289       0.033769             0.966231
# 2  1154.613712    930.623   7109.053766       0.028262             0.938924
# 3  8640.000000  37041.000  12539.653400              0             1.000000
# 4  9391.769473  37232.000  18456.154037       0.033769             0.966231
#
#    size_industry
# 0             71
# 1             69
# 2             67
# 3             69
# 4             62
#
# [5 rows x 28 columns]

# %%
#Save Data for regression (Done in R)
data.to_csv("data_all_1999_to_2022.csv")
